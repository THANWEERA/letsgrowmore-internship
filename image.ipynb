# %%
# !pip install image
# Out:
# Requirement already satisfied: image in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (1.5.33)
# Requirement already satisfied: pillow in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (from image) (9.1.0)
# Requirement already satisfied: django in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (from image) (4.0.4)
# Requirement already satisfied: six in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (from image) (1.16.0)
# Requirement already satisfied: asgiref<4,>=3.4.1 in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (from django->image) (3.5.0)
# Requirement already satisfied: tzdata in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (from django->image) (2022.1)
# Requirement already satisfied: sqlparse>=0.2.2 in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (from django->image) (0.4.2)

# %%
# !pip install display
# Out:
# Collecting display
#   Downloading display-1.0.0.tar.gz (687 bytes)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for display, since package 'wheel' is not installed.
# Installing collected packages: display
#   Running setup.py install for display: started
#   Running setup.py install for display: finished with status 'done'
# Successfully installed display-1.0.0

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\nourin\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.22.3)

# %%
from PIL import Image
from IPython.display import display
import cv2

# %%
img = cv2.imread('apple.jpg', 1)
img = cv2.resize(img, (640, 400))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=640x400>

# %%
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(img_grey))
# Out:
# <PIL.Image.Image image mode=L size=640x400>

# %%
img_inv = cv2.bitwise_not(img_grey)
display(Image.fromarray(img_inv))
# Out:
# <PIL.Image.Image image mode=L size=640x400>

# %%
img_smooth = cv2.GaussianBlur(img_inv, (5, 5), 0, 0)
display(Image.fromarray(img_smooth))
# Out:
# <PIL.Image.Image image mode=L size=640x400>

# %%
def dodge(img_grey, img_smooth):
  img_smooth_inv = 255 - img_smooth
  return cv2.divide(img_grey, img_smooth_inv, scale=256.0)

# %%
img_final = dodge(img_grey, img_smooth)
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=L size=640x400>

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=RGB size=640x400>
# <PIL.Image.Image image mode=L size=640x400>
